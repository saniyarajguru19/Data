# %% [markdown]
# <a href="https://colab.research.google.com/github/saniyarajguru19/Data/blob/main/DS_P7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Setup Github Account, loading data from different sources files format(csv,excel) and summarizing data with statistics.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
data=pd.read_csv("/content/Dataset.csv")
data
# Out:
#     ROLL NO      NAME CLASS DIV   ADDRESS
# 0         1    SANIYA    SY   A    PANVEL
# 1         2    SAKSHI    SY   C     VASHI
# 2         3   PRITHVI    TY   D   PALGHAR
# 3         4   BHUMIKA    FY   B    ALIBAG
# 4         5    RUTUJA    FY   B    PANVEL
# 5         6   VAIBHAV    TY   C     NERUL
# 6         7     ARYAN    SY   A  KHARGHAR
# 7         8    SNEHAL    SY   A  SEAWOODS
# 8         9  ABHIJEET    TY   B     VASHI
# 9        10    SIDDHI    FY   B    BANDRA
# 10       11   SHUBHAM    TY   C   CHEMBUR
# 11       12      ISHA    TY   D     KURLA
# 12       13   SHARAYU    FY   C   SNAPADA
# 13       14     HARSH    SY   A      ULWE
# 14       15     VIVEK    TY   B     THANE

# %%
data1=pd.read_excel("/content/Dataset1.xlsx")
data1
# Out:
#     ROLL NO      NAME CLASS DIV   ADDRESS
# 0         1    SANIYA    SY   A    PANVEL
# 1         2    SAKSHI    SY   C     VASHI
# 2         3   PRITHVI    TY   D   PALGHAR
# 3         4   BHUMIKA    FY   B    ALIBAG
# 4         5    RUTUJA    FY   B    PANVEL
# 5         6   VAIBHAV    TY   C     NERUL
# 6         7     ARYAN    SY   A  KHARGHAR
# 7         8    SNEHAL    SY   A  SEAWOODS
# 8         9  ABHIJEET    TY   B     VASHI
# 9        10    SIDDHI    FY   B    BANDRA
# 10       11   SHUBHAM    TY   C   CHEMBUR
# 11       12      ISHA    TY   D     KURLA
# 12       13   SHARAYU    FY   C   SNAPADA
# 13       14     HARSH    SY   A      ULWE
# 14       15     VIVEK    TY   B     THANE

# %%
img=mpimg.imread("/content/rolls.jpg")
plt.imshow(img)

# %% [markdown]
# #Summarizing data with statistics

# %%
df=pd.DataFrame({"Rollno":[6192,6212,6192,6190,6201],"Name":["Saniya","Sakshi","Saniya","Bhumika","Rutuja"],"Marks":[90,85,90,82,78],'class':["A","A","B","B","B"]})
df
# Out:
#    Rollno     Name  Marks class
# 0    6192   Saniya     90     A
# 1    6212   Sakshi     85     A
# 2    6192   Saniya     90     B
# 3    6190  Bhumika     82     B
# 4    6201   Rutuja     78     B

# %%
df.isnull()
# Out:
#    Sr.no  Rollno   Name
# 0  False   False  False
# 1  False   False  False
# 2  False   False  False
# 3  False   False  False
# 4  False   False  False

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of    Sr.no  Rollno   Name
# 0  False   False  False
# 1  False   False  False
# 2  False   False  False
# 3  False   False  False
# 4  False   False  False>

# %%
df.describe()
# Out:
#             Rollno      Marks
# count     5.000000   5.000000
# mean   6201.200000  81.200000
# std      10.281051   7.463243
# min    6190.000000  70.000000
# 25%    6192.000000  79.000000
# 50%    6201.000000  82.000000
# 75%    6211.000000  85.000000
# max    6212.000000  90.000000

# %%
df.describe(include='object')
# Out:
#           Name
# count        5
# unique       5
# top     Saniya
# freq         1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rollno  5 non-null      int64
#  1   Name    5 non-null      object
#  2   Marks   5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 248.0+ bytes

# %%
df.nunique()
# Out:
# Rollno    5
# Name      5
# Marks     5
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df['Name'].duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: Name, dtype: bool

# %%
df.nunique()
# Out:
# Rollno    4
# Name      4
# Marks     4
# dtype: int64

# %%
df.value_counts()
# Out:
# Rollno  Name     Marks
# 6192    Saniya   90       2
# 6190    Bhumika  82       1
# 6201    Rutuja   78       1
# 6212    Sakshi   85       1
# dtype: int64

# %%
df['Name'].value_counts()
# Out:
# Saniya     2
# Sakshi     1
# Bhumika    1
# Rutuja     1
# Name: Name, dtype: int64

# %%
df.nunique()
# Out:
# Rollno    4
# Name      4
# Marks     4
# class     2
# dtype: int64

# %%
df.value_counts()
# Out:
# Rollno  Name     Marks  class
# 6190    Bhumika  82     B        1
# 6192    Saniya   90     A        1
#                         B        1
# 6201    Rutuja   78     B        1
# 6212    Sakshi   85     A        1
# dtype: int64

# %%
df['class'].value_counts()
# Out:
# B    3
# A    2
# Name: class, dtype: int64

# %%
df['Marks'].mean()
# Out:
# 85.0

# %%
df['Marks'].var()
# Out:
# 27.0

# %%
df.corr()
# Out:
# <ipython-input-37-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           Rollno     Marks
# Rollno  1.000000 -0.297807
# Marks  -0.297807  1.000000

# %%
cor=df.corr()
# Out:
# <ipython-input-40-48d031cc9737>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=df.corr()

# %%
import seaborn as sns

# %%
sns.heatmap(cor, annot=True, fmt="2f", cmap="PiYG")
# Out:
# <Axes: >
